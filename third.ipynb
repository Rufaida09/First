# %% [markdown]
# <a href="https://colab.research.google.com/github/Rufaida09/First/blob/main/third.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("enter your age"))
if age>=18:
  print("You can vote")
else:
  print("You cannot vote")
# Out:
# enter your age15
# You cannot vote

# %%
num=int(input("enter number"))
if num>=1:
  print("Positive")
elif num<0:
  print("Negative")
else:
  print("the number is zero")
# Out:
# enter number-5
# Negative

# %%
num=int(input("Enter number"))
if (num % 2==0):
  print("even")
else :
  print("odd")
# Out:
# Enter number5
# odd

# %%
age=int(input("Enter age"))
if age<=12:
  id="child"
elif age<=19:
  id="teenager"
elif age<=64:
  id="adult"
else :
  id="senior"
print(f"You are identified as {id}")
# Out:
# Enter age13
# You are identified as teenager

# %%
def sum_of_natural_numbers(n):
 total_sum=0
 for i in range(1,n+1):
    total_sum+=i
 return total_sum




print(sum_of_natural_numbers(5))
# Out:
# 15

# %%
def factorial(n):
  factorial=1
  for i in range(1,n+1):
    factorial*=i


  return factorial
print(factorial(5))
# Out:
# 120

# %%
def multiplication_table(n):
  for j=range(1,11):


for i in range(1,n+1):

    mul=i*j
    j+=j



print(multiplication_table(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-787295007.py in <cell line: 0>()
#       8
#       9
# ---> 10 print(multiplication_table(5))
#      11
#      12
#
# /tmp/ipython-input-787295007.py in multiplication_table(n)
#       3   for i in range(1,n+1):
#       4
# ----> 5     mul=i*j
#       6     j+=j
#       7
#
# TypeError: unsupported operand type(s) for *: 'int' and 'range'

# %%
def multiplication_table(n):
  for j in range(1,11):
    mul=n*j
    j+=1
    print(mul)

 print(multiplication_table(5))
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# None
