# %% [markdown]
# <a href="https://colab.research.google.com/github/Rufaida09/First/blob/main/Second.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Rufaida"
age=33
favourite_color="Green"
print("Name:",name)
print("Age:",age)
print("Favourite color:",favourite_color)
# Out:
# Name: Rufaida
# Age: 33
# Favourite color: Green

# %%
length=7
width=5
Area=length*width
perimeter=2*length*width
print(Area)
print(perimeter)
# Out:
# 35
# 70

# %%
Foods=["Fuchka","Jhalmuri","Chotpoti","Khichuri","Panta"]
print(Foods[0])
print(Foods[4])
# Out:
# Fuchka
# Panta

# %%
numbers=[100,105,107,109,111]
print(numbers)
numbers.append(113)
print(numbers)
numbers.remove(107)
print(numbers)
numbers.sort()
print(numbers)
# Out:
# [100, 105, 107, 109, 111]
# [100, 105, 107, 109, 111, 113]
# [100, 105, 109, 111, 113]
# [100, 105, 109, 111, 113]

# %%
Me= {
    "age":34,
    "subject":"EEE",
    "course":["power","machine","circuit"]
}

# %%
Dhaka=(23.8,90.41)

# %%
c1={200,101,255}
c2={222,223,255}
union=c1|c2
print(union)
common=c1&c2
print(common)
# Out:
# {223, 101, 200, 222, 255}
# {255}

# %%
string="text"
print(string[1])
print(string[-1])
# Out:
# e
# t

# %%
"text".upper()
# Out:
# 'TEXT'
